# %%
import seaborn as snb

# %%
iris=snb.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
snb.scatterplot(x=iris.sepal_length ,y=iris.sepal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
snb.scatterplot(x=iris.sepal_length ,y=iris.petal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
snb.scatterplot(x=iris.sepal_length ,y=iris.petal_length)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
# this is used to plot hiso gram 
snb.displot(iris['sepal_length'])

# %%
snb.displot(iris['petal_length'])

# %%
tips=snb.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
snb.scatterplot(x=tips.total_bill,y=tips.size)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
snb.scatterplot(x=tips.total_bill,y=tips.smoker)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='smoker'>

# %%
snb.scatterplot(x=tips.total_bill,y=tips.sex)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
tips['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
snb.relplot(x=tips.total_bill,y=tips.size ,data=tips,hue='smoker')

# %%
snb.relplot(x=tips.total_bill,y=tips.size ,data=tips,hue='size')

# %%
snb.scatterplot(x=iris.sepal_length ,y=iris.sepal_width)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
snb.relplot(x=iris.sepal_length ,y=iris.sepal_width,data=iris , hue='petal_width')

# %%
snb.relplot(x=iris.sepal_length ,y=iris.sepal_width,data=iris , hue='species')

# %%
snb.relplot(x=iris.sepal_length ,y=iris.sepal_width,data=iris , style='species')

# %%
snb.relplot(x=iris.sepal_length ,y=iris.sepal_width,data=iris , style='species',hue='petal_width')

# %%
snb.catplot(x='smoker' , y='tip' ,data = tips)

# %%
snb.catplot(x='total_bill' , y='tip' ,data = tips)

# %%
# joinplot is the combination of histogram and scatter plot
snb.jointplot(x='total_bill' , y='tip' ,data = tips)

# %%
# it give all the comprision graoh
snb.pairplot(tips)

# %%
snb.pairplot(iris)
