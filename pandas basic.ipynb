# %%
import pandas as pd

# %%
df=pd.read_csv('annual-balance-sheets-2007-2021-provisional.csv')

# %%
df
# Out:
#        Period                         Inst_sector  Inst_sector_code
# 0     2007.03  Non-corporate business enterprises               121  \
# 1     2007.03  Non-corporate business enterprises               121
# 2     2007.03  Non-corporate business enterprises               121
# 3     2007.03  Non-corporate business enterprises               121
# 4     2007.03  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 6550  2021.03                   Total all sectors               900
# 6551  2021.03                   Total all sectors               900
# 6552  2021.03                   Total all sectors               900
# 6553  2021.03                   Total all sectors               900
# 6554  2021.03                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS
# 0                          Closing balance total assets    LE00000  \
# ...

# %%
df=df=pd.read_csv('annual-balance-sheets-2007-2021-provisional.csv')

# %%
df
# Out:
#        Period                         Inst_sector  Inst_sector_code
# 0     2007.03  Non-corporate business enterprises               121  \
# 1     2007.03  Non-corporate business enterprises               121
# 2     2007.03  Non-corporate business enterprises               121
# 3     2007.03  Non-corporate business enterprises               121
# 4     2007.03  Non-corporate business enterprises               121
# ...       ...                                 ...               ...
# 6550  2021.03                   Total all sectors               900
# 6551  2021.03                   Total all sectors               900
# 6552  2021.03                   Total all sectors               900
# 6553  2021.03                   Total all sectors               900
# 6554  2021.03                   Total all sectors               900
#
#                                              Descriptor SNA08TRANS
# 0                          Closing balance total assets    LE00000  \
# ...

# %%
df.head()
# Out:
#     Period                         Inst_sector  Inst_sector_code
# 0  2007.03  Non-corporate business enterprises               121  \
# 1  2007.03  Non-corporate business enterprises               121
# 2  2007.03  Non-corporate business enterprises               121
# 3  2007.03  Non-corporate business enterprises               121
# 4  2007.03  Non-corporate business enterprises               121
#
#                                           Descriptor SNA08TRANS
# 0                       Closing balance total assets    LE00000  \
# 1  Financial assets Closing balance total financi...    LE00000
# 2  Financial assets Closing balance monetary gold...    LE00000
# 3  Financial assets Closing balance currency and ...    LE00000
# 4   Financial assets Closing balance debt securities    LE00000
#
#   Asset_liability_code  Values
# 0              A000000  345973
# 1              AFA0000   99770
# 2              AFA0100       0
# 3              AFA0200   14773
# ...

# %%
df.tail()
# Out:
#        Period        Inst_sector  Inst_sector_code
# 6550  2021.03  Total all sectors               900  \
# 6551  2021.03  Total all sectors               900
# 6552  2021.03  Total all sectors               900
# 6553  2021.03  Total all sectors               900
# 6554  2021.03  Total all sectors               900
#
#                                              Descriptor SNA08TRANS
# 6550  Financial liabilities Closing balance other ac...    LE00000  \
# 6551  Financial assets Closing balance produced non-...    LE00000
# 6552  Financial assets Closing balance non-produced ...    LE00000
# 6553                          Closing balance net worth    LE00000
# 6554    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code   Values
# 6550              AFL0800   189843
# 6551              AN10000  1122154
# 6552              AN20000  1495556
# 6553              B900000  2617710
# 6554              L000000  6678433

# %%
df.head(3)
# Out:
#     Period                         Inst_sector  Inst_sector_code
# 0  2007.03  Non-corporate business enterprises               121  \
# 1  2007.03  Non-corporate business enterprises               121
# 2  2007.03  Non-corporate business enterprises               121
#
#                                           Descriptor SNA08TRANS
# 0                       Closing balance total assets    LE00000  \
# 1  Financial assets Closing balance total financi...    LE00000
# 2  Financial assets Closing balance monetary gold...    LE00000
#
#   Asset_liability_code  Values
# 0              A000000  345973
# 1              AFA0000   99770
# 2              AFA0100       0

# %%
df.tail(3)
# Out:
#        Period        Inst_sector  Inst_sector_code
# 6552  2021.03  Total all sectors               900  \
# 6553  2021.03  Total all sectors               900
# 6554  2021.03  Total all sectors               900
#
#                                              Descriptor SNA08TRANS
# 6552  Financial assets Closing balance non-produced ...    LE00000  \
# 6553                          Closing balance net worth    LE00000
# 6554    Closing balance total liabilities and net worth    LE00000
#
#      Asset_liability_code   Values
# 6552              AN20000  1495556
# 6553              B900000  2617710
# 6554              L000000  6678433

# %%
df.columns
# Out:
# Index(['Period', 'Inst_sector', 'Inst_sector_code', 'Descriptor', 'SNA08TRANS',
#        'Asset_liability_code', 'Values'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
a=df.dtypes
a
# Out:
# Period                  float64
# Inst_sector              object
# Inst_sector_code          int64
# Descriptor               object
# SNA08TRANS               object
# Asset_liability_code     object
# Values                   object
# dtype: object

# %%
list(a)
# Out:
# [dtype('float64'),
#  dtype('O'),
#  dtype('int64'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O'),
#  dtype('O')]

# %%
b=df['Period']

# %%
b
# Out:
# 0       2007.03
# 1       2007.03
# 2       2007.03
# 3       2007.03
# 4       2007.03
#          ...
# 6550    2021.03
# 6551    2021.03
# 6552    2021.03
# 6553    2021.03
# 6554    2021.03
# Name: Period, Length: 6555, dtype: float64

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
list(b)
# Out:
# [2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
#  2007.03,
# ...

# %%
# in the case of pass list return the data frame
c=df[['Period']]

# %%
c
# Out:
#        Period
# 0     2007.03
# 1     2007.03
# 2     2007.03
# 3     2007.03
# 4     2007.03
# ...       ...
# 6550  2021.03
# 6551  2021.03
# 6552  2021.03
# 6553  2021.03
# 6554  2021.03
#
# [6555 rows x 1 columns]

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
# in multipe element must used list
d=df[['Period', 'Inst_sector']]
d
# Out:
#        Period                         Inst_sector
# 0     2007.03  Non-corporate business enterprises
# 1     2007.03  Non-corporate business enterprises
# 2     2007.03  Non-corporate business enterprises
# 3     2007.03  Non-corporate business enterprises
# 4     2007.03  Non-corporate business enterprises
# ...       ...                                 ...
# 6550  2021.03                   Total all sectors
# 6551  2021.03                   Total all sectors
# 6552  2021.03                   Total all sectors
# 6553  2021.03                   Total all sectors
# 6554  2021.03                   Total all sectors
#
# [6555 rows x 2 columns]

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
# for the exeal data sheet
df1=pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
df1
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0          NaN         NaN         NaN  \
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2
# 0         NaN         NaN         NaN  \
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                                                NaN        NaN        NaN  \
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
df1.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2          Unnamed: 3 Unnamed: 4
# 0         NaN         NaN         NaN                 NaN        NaN  \
# 1         NaN         NaN         NaN  Datetimes in LUSID        NaN
# 2         NaN         NaN         NaN                 NaN        NaN
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN         NaN        NaN        NaN        NaN
# 1        NaN         NaN        NaN        NaN        NaN
# 2        NaN         NaN        NaN        NaN        NaN

# %%
df1.tail(3)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 25         NaN         NaN         NaN        NaN  \
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                               Unnamed: 4                  Unnamed: 5
# 25          Add an hour to your datetime  2019-04-10 14:30:45.550000  \
# 26                                   NaN                         NaN
# 27  Subtract a minute from your datetime  2019-04-10 14:29:45.550000
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 25         NaN        NaN        NaN        NaN
# 26         NaN        NaN        NaN        NaN
# 27         NaN        NaN        NaN        NaN

# %%
df1.tail()
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2 Unnamed: 3
# 23         NaN         NaN         NaN        NaN  \
# 24         NaN         NaN         NaN        NaN
# 25         NaN         NaN         NaN        NaN
# 26         NaN         NaN         NaN        NaN
# 27         NaN         NaN         NaN        NaN
#
#                                           Unnamed: 4
# 23  Although the date can still appears without time  \
# 24                                               NaN
# 25                      Add an hour to your datetime
# 26                                               NaN
# 27              Subtract a minute from your datetime
#
#                     Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 23  2019-04-10 13:30:45.550000         NaN        NaN        NaN        NaN
# 24                         NaN         NaN        NaN        NaN        NaN
# 25  2019-04-10 14:30:45.550000         NaN        NaN        NaN        NaN
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
f=df1.columns

# %%
f
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
type(f)
# Out:
# pandas.core.indexes.base.Index

# %%
list(f)
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9']

# %%
df1['Unnamed: 1']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# Name: Unnamed: 1, dtype: float64

# %%
df1[['Unnamed: 1']]
# Out:
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN

# %%
df1[['Unnamed: 1', 'Unnamed: 2']]
# Out:
#     Unnamed: 1  Unnamed: 2
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         NaN         NaN
# 16         NaN         NaN
# 17         NaN         NaN
# 18         NaN         NaN
# 19         NaN         NaN
# 20         NaN         NaN
# 21         NaN         NaN
# 22         NaN         NaN
# 23         NaN         NaN
# 24         NaN         NaN
# 25         NaN         NaN
# 26         NaN         NaN
# 27         NaN         NaN

# %%
df1[['Unnamed: 1', 'Unnamed: 2','Unnamed: 3', 'Unnamed: 4']]
# Out:
#     Unnamed: 1  Unnamed: 2                                         Unnamed: 3
# 0          NaN         NaN                                                NaN  \
# 1          NaN         NaN                                 Datetimes in LUSID
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN   This sheet allows you to format datetimes for...
# 4          NaN         NaN        If you have any questions please visit our:
# 5          NaN         NaN                                                NaN
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                                NaN
# 10         NaN         NaN                                                NaN
# ...

# %%
bn=df1.to_csv("dataframe")

# %%
url=pd.read_html("https://www.contextures.com/xlsampledata01.html")

# %%
url
# Out:
# [                                                   0
#  0  Key Skills > Sample Data Excel Sample Data Thi...,
#                                                     0
#  0  Why Use Sample Data in Excel? \tThis page has ...,
#                                                     0
#  0  1) Office Supply Sales Data  The first set of ...,
#                                                     0
#  0  2) Food Sales Data  This sample file has food ...,
#                                                     0
#  0  3) Workplace Safety Data  This sample file has...,
#                                                     0
#  0  4) Work Orders Data  This sample file has work...,
#                                                     0
#  0  5) Hockey Players Data  This sample file has d...,
#                                                     0
#  0  6) Winter Athletes Data  This sample Excel spr...,
#                                                     0
# ...

# %%
type(url)
# Out:
# list

# %%
len(url)
# Out:
# 17

# %%
a=url[0]

# %%
url[4]
# Out:
#                                                    0
# 0  3) Workplace Safety Data  This sample file has...

# %%
url[7]
# Out:
#                                                    0
# 0  6) Winter Athletes Data  This sample Excel spr...

# %%
a.head()
# Out:
#                                                    0
# 0  Key Skills > Sample Data Excel Sample Data Thi...

# %%
a.tail()
# Out:
#                                                    0
# 0  Key Skills > Sample Data Excel Sample Data Thi...

# %%
a.columns
# Out:
# Index([0], dtype='int64')

# %%
a.dtypes
# Out:
# 0    object
# dtype: object
